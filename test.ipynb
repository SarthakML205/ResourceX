# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://www.linkedin.com/feed/update/urn:li:activity:7302840480113799168/")

docs = loader.load()

docs[0]
# Out:
# Document(metadata={'source': 'https://www.linkedin.com/feed/update/urn:li:activity:7302840480113799168/', 'title': 'Irshad Ahamed on LinkedIn: ML for Microservices', 'description': 'Machine Learning in Microservices by Mohamed Abouahmed &amp; Omar Ahmed\n\nThis book explores how to productionize microservices architecture for machine learning…', 'language': 'en'}, page_content="\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nIrshad Ahamed on LinkedIn: ML for Microservices\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n              Agree & Join LinkedIn\n            \n\n      By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      Skip to main content\n    \n\n\n\nLinkedIn\n \n\n\n\n\n\n\n\n\n        Articles\n      \n\n\n\n\n\n\n\n        People\n      \n\n\n\n\n\n\n\n        Learning\n      \n\n\n\n\n\n\n\n        Jobs\n      \n\n\n\n\n\n\n\n        Games\n      \n\n\n\n\n\n\n      Join now\n    \n\n          Sign in\n      \n \n\n \n\n\n\n\n\n\n\n                  Irshad Ahamed’s Post\n\n\n\n\n\n\n\n\n \n\n\n\n              Irshad Ahamed\n            \n \n\n                AI Engineer | 🤗🍩🦙🦜🐼 | AGI enthusiastic | Researcher | Mathematician | Robotic🤖| 📈📊📉\n            \n \n\n                  \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      2d\n  \n \n \n\n \n\n\n\n\n\n\n\n\n\n\n\n\n                      Report this post\n                    \n    \n\n\n\n\n \n\n\n\nMachine Learning in Microservices by Mohamed Abouahmed & Omar Ahmed\n\nThis book explores how to productionize microservices architecture for machine learning solutions—an essential read for anyone looking to integrate ML into scalable, real-world applications.\n\nIf you're working with AI, ML, or cloud-based microservices, this is definitely a must-read. Looking forward to gaining insights and applying them in real-world projects!\n\nHave you read this book or worked with ML in microservices? Share your thoughts!\n\n#MachineLearning #Microservices #AI #ML #CloudComputing #TechReads\n\n \n\n\n\n\n\n\n\n\n\n\n                    80\n              \n\n\n \n\n \n\n\n\n \n\n\n\n\n\n      Like\n    \n\n\n\n\n\n      Comment\n    \n\n\n\n\n\n\n\n              Share\n            \n\n\n\n\n\nCopy\n\n\n\n\n\nLinkedIn\n\n\n\n\n\nFacebook\n\n\n\n\n\nTwitter\n\n\n\n\n \n\n\n\n\n        To view or add a comment, sign in\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n \n\n\n            5,082 followers\n          \n\n\n\n\n                    687 Posts\n                  \n\n\n\n                    3 Articles\n                  \n\n\n\n\n\n            View Profile\n          \n\n\nConnect\n\n\n\n\n\n\n              More from this author\n            \n\n\n\n\n\n\n\n\n\n \n\n\n            \n        Collection of educational resources encompassing Artificial Intelligence (AI) \n      \n \n\n\n\n\n\n            Irshad Ahamed\n          \n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      1y\n  \n          \n\n \n\n\n\n\n\n\n\n\n\n \n\n\n            \n        🚀 Embarking on a Tech Odyssey: Dive into the Dynamic World of AI/ML, NLP, and Beyond!\n      \n \n\n\n\n\n\n            Irshad Ahamed\n          \n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      1y\n  \n          \n\n \n\n\n\n\n\n\n\n\n\n \n\n\n            \n        Ways AI can catalyze human creativity\n      \n \n\n\n\n\n\n            Irshad Ahamed\n          \n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    ...

# %%
docs[0].page_content
# Out:
# "\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nIrshad Ahamed on LinkedIn: ML for Microservices\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n              Agree & Join LinkedIn\n            \n\n      By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      Skip to main content\n    \n\n\n\nLinkedIn\n \n\n\n\n\n\n\n\n\n        Articles\n      \n\n\n\n\n\n\n\n        People\n      \n\n\n\n\n\n\n\n        Learning\n      \n\n\n\n\n\n\n\n        Jobs\n      \n\n\n\n\n\n\n\n        Games\n      \n\n\n\n\n\n\n      Join now\n    \n\n          Sign in\n      \n \n\n \n\n\n\n\n\n\n\n                  Irshad Ahamed’s Post\n\n\n\n\n\n\n\n\n \n\n\n\n              Irshad Ahamed\n            \n \n\n                AI Engineer | 🤗🍩🦙🦜🐼 | AGI enthusiastic | Researcher | Mathematician | Robotic🤖| 📈📊📉\n            \n \n\n                  \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      2d\n  \n \n \n\n \n\n\n\n\n\n\n\n\n\n\n\n\n                      Report this post\n                    \n    \n\n\n\n\n \n\n\n\nMachine Learning in Microservices by Mohamed Abouahmed & Omar Ahmed\n\nThis book explores how to productionize microservices architecture for machine learning solutions—an essential read for anyone looking to integrate ML into scalable, real-world applications.\n\nIf you're working with AI, ML, or cloud-based microservices, this is definitely a must-read. Looking forward to gaining insights and applying them in real-world projects!\n\nHave you read this book or worked with ML in microservices? Share your thoughts!\n\n#MachineLearning #Microservices #AI #ML #CloudComputing #TechReads\n\n \n\n\n\n\n\n\n\n\n\n\n                    80\n              \n\n\n \n\n \n\n\n\n \n\n\n\n\n\n      Like\n    \n\n\n\n\n\n      Comment\n    \n\n\n\n\n\n\n\n              Share\n            \n\n\n\n\n\nCopy\n\n\n\n\n\nLinkedIn\n\n\n\n\n\nFacebook\n\n\n\n\n\nTwitter\n\n\n\n\n \n\n\n\n\n        To view or add a comment, sign in\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n \n\n\n            5,082 followers\n          \n\n\n\n\n                    687 Posts\n                  \n\n\n\n                    3 Articles\n                  \n\n\n\n\n\n            View Profile\n          \n\n\nConnect\n\n\n\n\n\n\n              More from this author\n            \n\n\n\n\n\n\n\n\n\n \n\n\n            \n        Collection of educational resources encompassing Artificial Intelligence (AI) \n      \n \n\n\n\n\n\n            Irshad Ahamed\n          \n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      1y\n  \n          \n\n \n\n\n\n\n\n\n\n\n\n \n\n\n            \n        🚀 Embarking on a Tech Odyssey: Dive into the Dynamic World of AI/ML, NLP, and Beyond!\n      \n \n\n\n\n\n\n            Irshad Ahamed\n          \n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      1y\n  \n          \n\n \n\n\n\n\n\n\n\n\n\n \n\n\n            \n        Ways AI can catalyze human creativity\n      \n \n\n\n\n\n\n            Irshad Ahamed\n          \n\n            \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n      2y\n  \n          \n\n \n\n\n\n\n\n\n\n\n              Explore topics\n            \n\n\n\n\n\n                Sales\n              \n\n\n\n                Marketing\n              \n\n\n\n                IT Services\n              \n\n\n\n                Business Administration\n   ...

# %%
import requests

url = "https://linkedin-api8.p.rapidapi.com/get-post"

querystring = {"url":"https://www.linkedin.com/feed/update/urn:li:activity:7302840480113799168/"}

headers = {
	"x-rapidapi-key": "61f38c7348msh0f0b1448d4616fep1e5c55jsn9e6131a31ffb",
	"x-rapidapi-host": "linkedin-api8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'success': True, 'message': '', 'data': {'isBrandPartnership': False, 'text': "Machine Learning in Microservices by Mohamed Abouahmed & Omar Ahmed\n\nThis book explores how to productionize microservices architecture for machine learning solutions—an essential read for anyone looking to integrate ML into scalable, real-world applications.\n\nIf you're working with AI, ML, or cloud-based microservices, this is definitely a must-read. Looking forward to gaining insights and applying them in real-world projects!\n\nHave you read this book or worked with ML in microservices? Share your thoughts!\n\n#MachineLearning #Microservices #AI #ML #CloudComputing #TechReads", 'totalReactionCount': 259, 'likeCount': 229, 'appreciationCount': 1, 'empathyCount': 10, 'InterestCount': 18, 'praiseCount': 1, 'commentsCount': 5, 'repostsCount': 81, 'shareUrl': 'https://www.linkedin.com/posts/irshadahamedmi_ml-for-microservices-activity-7302840480113799168-2TEJ', 'postedAt': '5d', 'postedDate': '2025-03-05 00:00:50.674 +0000 UTC', 'postedDateTimestamp': 1741132850674, 'urn': '7302840480113799168', 'shareUrn': 'urn:li:ugcPost:7302840324995850241', 'author': {'id': 900634231, 'firstName': 'Irshad', 'lastName': 'Ahamed', 'headline': 'AI Engineer | 🤗🍩🦙🦜🐼 | AGI enthusiastic | Researcher | Mathematician | Robotic🤖| 📈📊📉', 'username': 'irshadahamedmi', 'url': 'https://www.linkedin.com/in/irshadahamedmi', 'profilePictures': [{'width': 100, 'height': 100, 'url': 'https://media.licdn.com/dms/image/v2/D5603AQFdHsrWX6OseQ/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1704561163945?e=1747267200&v=beta&t=tYuqGKRkSwY9CNr5JvAu1nHK1XhObng88S6x5Uwv0Os'}, {'width': 200, 'height': 200, 'url': 'https://media.licdn.com/dms/image/v2/D5603AQFdHsrWX6OseQ/profile-displayphoto-shrink_200_200/profile-displayphoto-shrink_200_200/0/1704561163945?e=1747267200&v=beta&t=oYxdZtjzodHVFm3XBxGq16IQ13MzKVH3GRMut9YK98o'}, {'width': 400, 'height': 400, 'url': 'https://media.licdn.com/dms/image/v2/D5603AQFdHsrWX6OseQ/profile-displayphoto-shrink_400_400/profile-displayphoto-shrink_400_400/0/1704561163945?e=1747267200&v=beta&t=NJs6mnBlK3L9jHqt_yG59jBM2Ic68BXhqQ6GHAWTb4o'}, {'width': 800, 'height': 800, 'url': 'https://media.licdn.com/dms/image/v2/D5603AQFdHsrWX6OseQ/profile-displayphoto-shrink_800_800/profile-displayphoto-shrink_800_800/0/1704561163945?e=1747267200&v=beta&t=cl9XLa1AyGzi_jupWg3YwNKirofPoD6mXKCvbZ5mxCk'}], 'urn': 'ACoAADWulncB6NEQdQm1F-hfxRtPp0QCZc7PTUY'}, 'company': {}, 'document': {'title': 'ML for Microservices ', 'urn': 'D561FAQH8rQdBhiOt1w', 'TranscribedDocumentUrl': 'https://media.licdn.com/dms/document/media/v2/D561FAQH8rQdBhiOt1w/feedshare-document-url-metadata-scrapper-pdf/B56ZVjmYL3GsA0-/0/1741132789162?e=1742194800&v=beta&t=-TmRxTHfnQ079T3M_6PnTKleswMAaczGW9Hj6HIFD1o', 'TranscribedDocumentUrlExpiresAt': 1742194800000, 'manifestUrlExpiresAt': 1742194800000, 'manifestUrl': 'https://media.licdn.com/dms/document/pl/v2/D561FAQH8rQdBhiOt1w/feedshare-document-master-manifest/B56ZVjmYL3GsBY-/0/1741132847600?e=1742194800&v=beta&t=7ewS_dkMlFxtei6j--MRwQIYHQJyIAPXR-fQ3QjFNSg', 'scanRequiredForDownload': True, 'totalPageCount': 270, 'coverPages': [{'width': 389, 'height': 480, 'imageUrls': ['https://media.licdn.com/dms/image/v2/D561FAQH8rQdBhiOt1w/feedshare-document-cover-images_480/B56ZVjmYL3GsBI-/0/1741132802841?e=1742194800&v=beta&t=eFxKgGxXdbb1eQLPDpZwT90obzN87PwwhitcogqlHpI', 'https://media.licdn.com/dms/image/v2/D561FAQH8rQdBhiOt1w/feedshare-document-cover-images_480/B56ZVjmYL3GsBI-/1/1741132802841?e=1742194800&v=beta&t=LBami7eSflJzXeD11955sBUj_DURbwvvfxnJbCM4j1s', 'https://media.licdn.com/dms/image/v2/D561FAQH8rQdBhiOt1w/feedshare-document-cover-images_480/B56ZVjmYL3GsBI-/2/1741132802841?e=1742194800&v=beta&t=KQhekUOlHbl9GXx_8z6v2y2l_afh_oln5g8vwPfCST0']}, {'width': 652, 'height': 804, 'imageUrls': ['https://media.licdn.com/dms/image/v2/D561FAQH8rQdBhiOt1w/feedshare-document-cover-images_800/B56ZVjmYL3GsBA-/0/1741132815549?e=1742194800&v=beta& ...

# %%
import requests

url = "https://linkedin-api8.p.rapidapi.com/get-post-reactions"

payload = {
	"url": "https://www.linkedin.com/posts/kalyanksnlp_ml-and-llm-system-design-500-case-studies-activity-7303665168939372544-9q6Q?utm_source=share&utm_medium=member_desktop&rcm=ACoAADx7OvMBNe5rKXi5tJf8VHWCicO_ChephCY/?utm_source=share&utm_medium=member_desktop",
	"page": 1
}
headers = {
	"x-rapidapi-key": "61f38c7348msh0f0b1448d4616fep1e5c55jsn9e6131a31ffb",
	"x-rapidapi-host": "linkedin-api8.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'success': True, 'message': '', 'data': {'currentPage': 1, 'items': [{'id': 24804784, 'urn': 'ACoAAAF6fbABEYjmrD_kk3UNUYQas8BHrV-bU6g', 'fullName': 'Vijay Gunti', 'profileType': 'user', 'profileUrl': 'https://www.linkedin.com/in/ACoAAAF6fbABEYjmrD_kk3UNUYQas8BHrV-bU6g', 'reactionType': 'LIKE', 'profilePicture': None, 'headline': 'Building Generative AI , Single and Multiple Agents for Enterprises | Mentor | Agentic AI expert | Advisor | Gen AI Lead/Architect | Authoring Gen AI Agents Book'}, {'id': 909824898, 'urn': 'ACoAADY604IBsk4Asq-2oSe1DbJJKwfo0eJxn8g', 'fullName': 'Shreyas Chandolkar', 'profileType': 'user', 'profileUrl': 'https://www.linkedin.com/in/ACoAADY604IBsk4Asq-2oSe1DbJJKwfo0eJxn8g', 'reactionType': 'LIKE', 'profilePicture': [{'width': 100, 'height': 100, 'url': 'https://media.licdn.com/dms/image/v2/D4D03AQGuZ4qn28NUfw/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1721704414227?e=1746662400&v=beta&t=bMda7jzy4akGdrsjBpYNTk4fFVpNh35twZuakXGRLVc'}, {'width': 200, 'height': 200, 'url': 'https://media.licdn.com/dms/image/v2/D4D03AQGuZ4qn28NUfw/profile-displayphoto-shrink_200_200/profile-displayphoto-shrink_200_200/0/1721704414227?e=1746662400&v=beta&t=-TEJcGXJhD7H8jNvYNZ3hy_LgtmjWTjFTj7ffuo12S4'}, {'width': 400, 'height': 400, 'url': 'https://media.licdn.com/dms/image/v2/D4D03AQGuZ4qn28NUfw/profile-displayphoto-shrink_400_400/profile-displayphoto-shrink_400_400/0/1721704414227?e=1746662400&v=beta&t=0yuR4Z1Ox-lzrGB7FlF-SSkqSBwKYI9E2C4f0aWMVDk'}, {'width': 800, 'height': 800, 'url': 'https://media.licdn.com/dms/image/v2/D4D03AQGuZ4qn28NUfw/profile-displayphoto-shrink_800_800/profile-displayphoto-shrink_800_800/0/1721704414227?e=1746662400&v=beta&t=HJ9Y2eG9pO-UR8bZ2tSKmcaTOFOhGBPv2rtm3NQLhgQ'}], 'headline': "Robotics @Flytbase | PICT'24"}, {'id': 385113386, 'urn': 'ACoAABb0XSoBq0IS4xcOYIkemCSqvHMrf144SYs', 'fullName': 'Gizem C.', 'profileType': 'user', 'profileUrl': 'https://www.linkedin.com/in/ACoAABb0XSoBq0IS4xcOYIkemCSqvHMrf144SYs', 'reactionType': 'LIKE', 'profilePicture': None, 'headline': 'AI Research Engineer'}, {'id': 1367250947, 'urn': 'ACoAAFF-mAMB3M6VFUrj8SyVUqtxGfyTLbrADsY', 'fullName': 'Mansi Marathe', 'profileType': 'user', 'profileUrl': 'https://www.linkedin.com/in/ACoAAFF-mAMB3M6VFUrj8SyVUqtxGfyTLbrADsY', 'reactionType': 'LIKE', 'profilePicture': [{'width': 800, 'height': 800, 'url': 'https://media.licdn.com/dms/image/v2/D5603AQGkqxZw8ztJYg/profile-displayphoto-shrink_800_800/B56ZVQ5rXhHsAg-/0/1740819053142?e=1746662400&v=beta&t=0MUwUXaNXYLoiSp-9lQupmwK5oyakGBJ3xaBptCY5ek'}, {'width': 400, 'height': 400, 'url': 'https://media.licdn.com/dms/image/v2/D5603AQGkqxZw8ztJYg/profile-displayphoto-shrink_400_400/B56ZVQ5rXhHsAk-/0/1740819053142?e=1746662400&v=beta&t=7J6hxJomc3yihXZIIgdvuN7Lo1tlb77V8fw2IKWhjxQ'}, {'width': 100, 'height': 100, 'url': 'https://media.licdn.com/dms/image/v2/D5603AQGkqxZw8ztJYg/profile-displayphoto-shrink_100_100/B56ZVQ5rXhHsAY-/0/1740819053142?e=1746662400&v=beta&t=gB3LMo8j_aEz9kpcRFdc4wxwRsgJG_Qq2obVq5pgk7k'}, {'width': 200, 'height': 200, 'url': 'https://media.licdn.com/dms/image/v2/D5603AQGkqxZw8ztJYg/profile-displayphoto-shrink_200_200/B56ZVQ5rXhHsAc-/0/1740819053105?e=1746662400&v=beta&t=MZNWBoaeLPvbzyySlO0tW0RSHIiwiFeJBTEDiKLK01E'}], 'headline': 'Student at Savitribai Phule Pune University'}, {'id': 764814040, 'urn': 'ACoAAC2WItgBdFUkzi1lWKSgW2Gz53ZtvgUQ-FU', 'fullName': 'Md Abdullah Al Hasib', 'profileType': 'user', 'profileUrl': 'https://www.linkedin.com/in/ACoAAC2WItgBdFUkzi1lWKSgW2Gz53ZtvgUQ-FU', 'reactionType': 'LIKE', 'profilePicture': [{'width': 400, 'height': 400, 'url': 'https://media.licdn.com/dms/image/v2/D5635AQEh2drz1okGQg/profile-framedphoto-shrink_400_400/profile-framedphoto-shrink_400_400/0/1713670576776?e=1741946400&v=beta&t=-cH46soPszh1BesL5GPWbwmgRECaDOeZNrnqGgHT-y4'}, {'width': 200, 'height': 200, 'url': 'https://media.licdn.com/dms/image/v2/D5635AQEh2drz1okGQg/profile-framedphoto-shrink_200_200/profile-framedphoto-shrink_200_200/0/ ...

# %%
import requests

url = "https://social-media-video-downloader.p.rapidapi.com/smvd/get/instagram"

querystring = {"url":"https://www.instagram.com/reel/DE76XY2ImBy/?igsh=MWV6aDBkMWQ2Z24="}

headers = {
	"x-rapidapi-key": "61f38c7348msh0f0b1448d4616fep1e5c55jsn9e6131a31ffb",
	"x-rapidapi-host": "social-media-video-downloader.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'success': True, 'message': None, 'src_url': 'https://www.instagram.com/reel/DE76XY2ImBy/?igsh=MWV6aDBkMWQ2Z24=', 'title': "Nebius AI Studio by @nebiusgroup is the ultimate kit every data scientist needs to push projects to production. 💚✅💻\n\n- 4.5x times faster than traditional tools\n- From prototype to scalable solutions in production \n- Reliable and cost-effective Inference platforms \n\nBest part, you don't need to be an MLOps\xa0 expert to use it. Experiment, play around and build. \n\nComment Nebius to get started or check the link in my profile 👇🏻🔗 \n\n#nebius #aistudio #aitools #mlops #inference #prototype #modeldeployment #cicd #machinelearning #machinelearningalgorithms #deeplearning #neuralnetworks #datascientist", 'author': {'username': 'codingmermaid.ai'}, 'stats': {'likes': '1,047', 'comment_count': '46', 'date': 'January 17, 2025'}, 'picture': 'https://scontent-lga3-3.cdninstagram.com/v/t51.2885-15/473085551_1160890768941352_4487641204345329375_n.jpg?stp=dst-jpg_e15_tt6&_nc_ht=scontent-lga3-3.cdninstagram.com&_nc_cat=104&_nc_oc=Q6cZ2AFheVpcbwEk7WSpoypu5Bdc8zqAlZUFFdCw_bimWvSzNPLkqDa0VALFYHVozjTWLdWWwpMRM91efYiLDaC1bOCx&_nc_ohc=OTglG-OxcP0Q7kNvgHGQX0S&_nc_gid=d95e98d2823047e4ad201572fe08fdf4&edm=ANTKIIoBAAAA&ccb=7-5&oh=00_AYGWSwP6714_aVDnAnogvB_2ia3WXbaveuUZQxaWY1uLKw&oe=67D4668C&_nc_sid=d885a2', 'images': [], 'links': [{'quality': 'audio_0', 'link': 'https://scontent-lga3-1.cdninstagram.com/o1/v/t16/f2/m69/AQMWIWMnc-ZZf1NpnzIXFVmqUV--VJ5N2UWIoPa0bgYyGPiQMVNe0b9xREoYGG6_lZ52ABYJ66Zffw_yKdPnSbNe.mp4?strext=1&_nc_cat=103&_nc_sid=9ca052&_nc_ht=scontent-lga3-1.cdninstagram.com&_nc_ohc=o_1zRJuiJpIQ7kNvgG5Qgss&efg=eyJ2ZW5jb2RlX3RhZyI6ImlnLXhwdmRzLmNsaXBzLmMyLUMzLmRhc2hfbG5faGVhYWNfdmJyM19hdWRpbyIsInZpZGVvX2lkIjpudWxsLCJjbGllbnRfbmFtZSI6ImlnIiwib2lsX3VybGdlbl9hcHBfaWQiOjkzNjYxOTc0MzM5MjQ1OSwidXJsZ2VuX3NvdXJjZSI6Ind3dyJ9&ccb=17-1&_nc_zt=28&oh=00_AYGlwQ6VMygofdy92qmTwg--z0rbgq1JiYNwj85JpI6t9g&oe=67D46885'}, {'quality': 'video_hd_original_0', 'link': 'https://scontent-lga3-1.cdninstagram.com/o1/v/t16/f2/m86/AQPjV7kSsdeOfYw8-Y3YjCxISNNcvKVeaA1x4518L-nuLD6Tll9CQKaC6uw6dE-3eG8W59W0UdlJSVM0izfJqylli5b58a_eVnuxISs.mp4?stp=dst-mp4&efg=eyJxZV9ncm91cHMiOiJbXCJpZ193ZWJfZGVsaXZlcnlfdnRzX290ZlwiXSIsInZlbmNvZGVfdGFnIjoidnRzX3ZvZF91cmxnZW4uY2xpcHMuYzIuNzIwLmJhc2VsaW5lIn0&_nc_cat=103&vs=1663474644297648_2656686256&_nc_vs=%3D%3D&_nc_rid=d95e9402aa&ccb=9-4&oh=00_AYH53_jlVfvv290094FfuQF-8dnoFYOem8WccYS5UBnAhg&oe=67D076EB&_nc_sid=d885a2&dl=1'}], 'r_id': 'TTl3tvPSOE', 'timeTaken': '1196.78ms'}

# %%
import re

# URL to extract the number from
url = "https://arxiv.org/abs/2503.05240"

# Define the regex pattern to match the number
pattern = r'\d+\.\d+'

# Search for the pattern in the URL
match = re.search(pattern, url)

# Extract and print the number if found
if match:
    number = match.group()
    print(f"Extracted number: {number}")
else:
    print("No number found in the URL.")
# Out:
# Extracted number: 2503.05240

# %%
import arxiv

client = arxiv.Client()

search_by_id = arxiv.Search(id_list=[number])
first_result = next(client.results(search_by_id))

json_result = { 'Title' : first_result.title, 'Authors' : first_result.authors, 'Abstract' : first_result.summary, 'url' : [first_result.pdf_url, first_result.links], 'categories' : first_result.categories } 

print(json_result)
# Out:
# {'Title': 'Mining Q&A Platforms for Empirical Evidence on Quantum Software Programming', 'Authors': [arxiv.Result.Author('Arif Ali Khan'), arxiv.Result.Author('Boshuai Ye'), arxiv.Result.Author('Muhammad Azeem Akbar'), arxiv.Result.Author('Javed Ali Khan'), arxiv.Result.Author('Davoud Mougouei'), arxiv.Result.Author('Xinyuan Ma')], 'Abstract': 'The rise of quantum computing has driven the need for quantum software\nengineering, yet its programming landscape remains largely unexplored in\nempirical research. As quantum technologies advance toward industrial adoption,\nunderstanding programming aspects is crucial to addressing software development\nchallenges. This study analyzes 6,935 quantum software programming discussion\nposts from Stack Exchange platforms (Quantum Computing, Stack Overflow,\nSoftware Engineering, and Code Review). Using topic modeling and qualitative\nanalysis, we identified key discussion topics, trends (popular and difficult),\ntools/frameworks, and practitioner challenges. Twenty topics were identified,\nincluding popular ones such as physical theories and mathematical foundations,\nas well as security and encryption algorithms, while the most difficult were\nobject-oriented programming and parameter control in quantum algorithms.\nAdditionally, we identified nine frameworks that support quantum programming,\nwith Qiskit emerging as the most widely adopted. Our findings also reveal core\nchallenges in quantum software programming, thematically mapped into four\nareas: theories and mathematical concepts, algorithms and applications,\nexperimental practices and software development, and education and community\nengagement. This study provides empirical insights that can inform future\nresearch, tool development, and educational efforts, supporting the evolution\nof the quantum software ecosystem.', 'url': ['http://arxiv.org/pdf/2503.05240v1', [arxiv.Result.Link('http://arxiv.org/abs/2503.05240v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/2503.05240v1', title='pdf', rel='related', content_type=None)]], 'categories': ['cs.SE']}

# %%
print(re.findall(pattern,url))
# Out:
# ['2503.05240']

# %%
match
# Out:
# <re.Match object; span=(22, 32), match='2503.05240'>

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://ai.meta.com/research/publications/large-concept-models-language-modeling-in-a-sentence-representation-space/")

docs = loader.load()

type(docs[0].metadata)

docs[0].metadata
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# {'source': 'https://ai.meta.com/research/publications/large-concept-models-language-modeling-in-a-sentence-representation-space/',
#  'title': 'Large Concept Models: Language Modeling in a Sentence Representation Space | Research - AI at Meta',
#  'description': 'LLMs have revolutionized the field of artificial intelligence and have emerged as the de-facto tool for\nmany tasks. The current established technology of...',
#  'language': 'en'}

# %%
from groq import Groq
from pydantic import BaseModel
from typing import Optional, List

#Custom output class
class Output(BaseModel):
    Post_Link : str
    Title : str
    Description : str
    resource_type : Optional[List[str]] = None
    platform : str
    Resource_link : Optional[List[str]] = None
    Resource_description : Optional[List[str]] = None
    Account : str


client = Groq(api_key= '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',)

chat_completion = client.chat.completions.create(
    #
    # Required parameters
    #
    messages=[
        # Set an optional system message. This sets the behavior of the
        # assistant and can be used to provide specific instructions for
        # how it should behave throughout the conversation.
        {
            "role": "system",
            "content": "you are my assistant whose task is to manage the resources that I will provide you and analyze them and generate result based on my output format. "
        },
        # Set a user message for the assistant to respond to.
        {
            "role": "user",
            "content": f"Analyze the content : {docs[0].metadata}",
        }
    ],

    # The language model which will generate the completion.
    model="deepseek-r1-distill-llama-70b",

    #
    # Optional parameters
    #

    # Controls randomness: lowering results in less random completions.
    # As the temperature approaches zero, the model will become deterministic
    # and repetitive.
    temperature=0.5,

    # The maximum number of tokens to generate. Requests can use up to
    # 32,768 tokens shared between prompt and completion.
    max_completion_tokens=1024,

    # Controls diversity via nucleus sampling: 0.5 means half of all
    # likelihood-weighted options are considered.
    top_p=1,

    # A stop sequence is a predefined or user-specified text string that
    # signals an AI to stop generating content, ensuring its responses
    # remain focused and concise. Examples include punctuation marks and
    # markers like "[end]".
    stop=None,

    response_format= Output,

    # If set, partial message deltas will be sent.
    stream=False,
)

# Print the completion returned by the LLM.
print(chat_completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 19
#      14     Account : str
#      17 client = Groq(api_key= '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',)
# ---> 19 chat_completion = client.chat.completions.create(
#      20     #
#      21     # Required parameters
#      22     #
#      23     messages=[
#      24         # Set an optional system message. This sets the behavior of the
#      25         # assistant and can be used to provide specific instructions for
#      26         # how it should behave throughout the conversation.
#      27         {
#      28             "role": "system",
#      29             "content": "you are my assistant whose task is to manage the resources that I will provide you and analyze them and generate result based on my output format. "
#      30         },
#      31         # Set a user message for the assistant to respond to.
#      32         {
#      33             "role": "user",
#      34             "content": f"Analyze the content : {docs[0].metadata}",
#      35         }
#      36     ],
#      37
#      38     # The language model which will generate the completion.
#      39     model="deepseek-r1-distill-llama-70b",
#      40
#      41     #
#      42     # Optional parameters
#      43     #
#      44
#      45     # Controls randomness: lowering results in less random completions.
#      46     # As the temperature approaches zero, the model will become deterministic
#      47     # and repetitive.
#      48     temperature=0.5,
#      49
#      50     # The maximum number of tokens to generate. Requests can use up to
#      51     # 32,768 tokens shared between prompt and completion.
#      52     max_completion_tokens=1024,
#      53
#      54     # Controls diversity via nucleus sampling: 0.5 means half of all
#      55     # likelihood-weighted options are considered.
#      56     top_p=1,
#      57
#      58     # A stop sequence is a predefined or user-specified text string that
#      59     # signals an AI to stop generating content, ensuring its responses
#      60     # remain focused and concise. Examples include punctuation marks and
#      61     # markers like "[end]".
#      62     stop=None,
#      63
#      64     response_format= Output,
#      65
#      66     # If set, partial message deltas will be sent.
#      67     stream=False,
#      68 )
#      70 # Print the completion returned by the LLM.
#      71 print(chat_completion.choices[0].message.content)
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\site-packages\groq\resources\chat\completions.py:322, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, reasoning_format, response_format, seed, service_tier, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     166 def create(
#     167     self,
#     168     *,
#    (...)
#     198     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     199 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     200     """
#     201     Creates a model response for the given chat conversation.
#     202
#    (...)
#     320       timeout: Override the client-level default timeout for this request, in seconds
#     321     """
# --> 322     return self._post(
#     323         "/openai/v1/chat/completions",
#     324         body=maybe_transform(
#     325             {
#     326                 "messages": messages,
#     327                 "model": model,
#     328                 "frequency_penalty": frequency_penalty,
#     329                 "function_call": function_call,
#     330                 "functions": functions,
#     331                 "logit_bias": logit_bias,
#     332                 "logprobs": logprobs,
#     333                 "max_completion_tokens": max_completion_tokens,
#     334                 "max_tokens": max_tokens,
#     335                 "n": n,
#     336                 "parallel_tool_calls": parallel_tool_calls,
#     337                 "presence_penalty": presence_penalty,
#     338                 "reasoning_format": reasoning_format,
#     339                 "response_format": response_format,
#     340                 "seed": seed,
#     341                 "service_tier": service_tier,
#     342                 "stop": stop,
#     343                 "stream": stream,
#     344                 "temperature": temperature,
#     345                 "tool_choice": tool_choice,
#     346                 "tools": tools,
#     347                 "top_logprobs": top_logprobs,
#     348                 "top_p": top_p,
#     349                 "user": user,
#     350             },
#     351             completion_create_params.CompletionCreateParams,
#     352         ),
#     353         options=make_request_options(
#     354             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     355         ),
#     356         cast_to=ChatCompletion,
#     357         stream=stream or False,
#     358         stream_cls=Stream[ChatCompletionChunk],
#     359     )
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\site-packages\groq\_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\site-packages\groq\_base_client.py:958, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     955 else:
#     956     retries_taken = 0
# --> 958 return self._request(
#     959     cast_to=cast_to,
#     960     options=options,
#     961     stream=stream,
#     962     stream_cls=stream_cls,
#     963     retries_taken=retries_taken,
#     964 )
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\site-packages\groq\_base_client.py:984, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     981 options = self._prepare_options(options)
#     983 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# --> 984 request = self._build_request(options, retries_taken=retries_taken)
#     985 self._prepare_request(request)
#     987 kwargs: HttpxSendArgs = {}
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\site-packages\groq\_base_client.py:504, in BaseClient._build_request(self, options, retries_taken)
#     501     kwargs["extensions"] = {"sni_hostname": prepared_url.host.replace("_", "-")}
#     503 # TODO: report this error to httpx
# --> 504 return self._client.build_request(  # pyright: ignore[reportUnknownMemberType]
#     505     headers=headers,
#     506     timeout=self.timeout if isinstance(options.timeout, NotGiven) else options.timeout,
#     507     method=options.method,
#     508     url=prepared_url,
#     509     # the `Query` type that we use is incompatible with qs'
#     510     # `Params` type as it needs to be typed as `Mapping[str, object]`
#     511     # so that passing a `TypedDict` doesn't cause an error.
#     512     # https://github.com/microsoft/pyright/issues/3526#event-6715453066
#     513     params=self.qs.stringify(cast(Mapping[str, Any], params)) if params else None,
#     514     json=json_data,
#     515     files=files,
#     516     **kwargs,
#     517 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:378, in BaseClient.build_request(self, method, url, content, data, files, json, params, headers, cookies, timeout, extensions)
#     372     timeout = (
#     373         self.timeout
#     374         if isinstance(timeout, UseClientDefault)
#     375         else Timeout(timeout)
#     376     )
#     377     extensions = dict(**extensions, timeout=timeout.as_dict())
# --> 378 return Request(
#     379     method,
#     380     url,
#     381     content=content,
#     382     data=data,
#     383     files=files,
#     384     json=json,
#     385     params=params,
#     386     headers=headers,
#     387     cookies=cookies,
#     388     extensions=extensions,
#     389 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_models.py:408, in Request.__init__(self, method, url, params, headers, cookies, content, data, files, json, stream, extensions)
#     406 if stream is None:
#     407     content_type: str | None = self.headers.get("content-type")
# --> 408     headers, stream = encode_request(
#     409         content=content,
#     410         data=data,
#     411         files=files,
#     412         json=json,
#     413         boundary=get_multipart_boundary_from_content_type(
#     414             content_type=content_type.encode(self.headers.encoding)
#     415             if content_type
#     416             else None
#     417         ),
#     418     )
#     419     self._prepare(headers)
#     420     self.stream = stream
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_content.py:216, in encode_request(content, data, files, json, boundary)
#     214     return encode_urlencoded_data(data)
#     215 elif json is not None:
# --> 216     return encode_json(json)
#     218 return {}, ByteStream(b"")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_content.py:177, in encode_json(json)
#     176 def encode_json(json: Any) -> tuple[dict[str, str], ByteStream]:
# --> 177     body = json_dumps(
#     178         json, ensure_ascii=False, separators=(",", ":"), allow_nan=False
#     179     ).encode("utf-8")
#     180     content_length = str(len(body))
#     181     content_type = "application/json"
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\json\encoder.py:261, in JSONEncoder.iterencode(self, o, _one_shot)
#     256 else:
#     257     _iterencode = _make_iterencode(
#     258         markers, self.default, _encoder, indent, floatstr,
#     259         self.key_separator, self.item_separator, self.sort_keys,
#     260         self.skipkeys, _one_shot)
# --> 261 return _iterencode(o, 0)
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type ModelMetaclass is not JSON serializable

# %%
from pydantic import BaseModel
from typing import Optional, List
from langchain.chat_models import init_chat_model
import getpass
import os

#Custom output class
class Output(BaseModel):
    Post_Link : Optional[str]
    Title : Optional[str] 
    Description : Optional[str] 
    resource_type : Optional[List[str]] = None
    platform : Optional[str]  
    Resource_link : Optional[List[str]] = None
    Resource_description : Optional[List[str]] = None
    Account : Optional[str] = None

model = GroqModel('deepseek-r1-distill-llama-70b', api_key='')


if not os.environ.get("GROQ_API_KEY"):
  os.environ["GROQ_API_KEY"] = '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'

llm = init_chat_model("deepseek-r1-distill-llama-70b", model_provider="groq")

structured_llm = llm.with_structured_output(Output)

llm_output = structured_llm.invoke(f"you are serving me as an assitant, whose task is to Analyze the content : {response.json()}, and provide me result in provided format and keep the relevant infomartion only")

# %%
import google_sheets
from googleapiclient.errors import HttpError
import asyncio


async def write_to_sheet(data_dict):
    """Write the LLM agent results to Google Sheets with proper headers"""
    try:
        # Get the sheet service using our utility function
        sheet = google_sheets.get_sheets_service()
        print("Successfully got Google Sheets service")
        
        # Check if sheet already has data
        result = sheet.values().get(
            spreadsheetId=google_sheets.sheet_id,
            range='Sheet1'
        ).execute()
        values = result.get('values', [])
        
        # If sheet is empty or has no headers, add them
        if not values:
            # Define headers based on Output model fields
            headers = ["Post_Link", "Title", "Description", "resoure_type", 
                      "platform", "Resource_link", "Resource_Description", "Account"]
            
            sheet.values().update(
                spreadsheetId=google_sheets.sheet_id,
                range='Sheet1!A1',
                valueInputOption='USER_ENTERED',
                body={'values': [headers]}
            ).execute()
            print("Added headers to sheet")
        
        # Prepare data row from dictionary
        row_data = [
            data_dict.get('Post_Link', ''),
            data_dict.get('Title', ''),
            data_dict.get('Description', ''),
            ' , '.join(data_dict.get('resoure_type', [])),
            data_dict.get('platform', ''),
            ' , '.join(data_dict.get('Resource_link', [])),
            ' , '.join(
                data_dict.get('Resoure_description', [])
            ) if 'Resoure_description' in data_dict else '',
            data_dict.get('Account', '')
        ]
        
        print("Appending data to sheet...")
        # Append data to the next available row
        result = sheet.values().append(
            spreadsheetId=google_sheets.sheet_id,
            range='Sheet1',
            valueInputOption='USER_ENTERED',
            body={'values': [row_data]}
        ).execute()
        
        print(f"{result.get('updates').get('updatedCells')} cells updated.")
        sheet_url = f"https://docs.google.com/spreadsheets/d/{google_sheets.sheet_id}/edit"
        print(f"View your sheet at: {sheet_url}")
        return True
        
    except HttpError as err:
        print(f"An error occurred with the API: {err}")
        return False
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        import traceback
        traceback.print_exc()
        return False

asyncio.run(write_to_sheet(llm_output))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 71
#      68         traceback.print_exc()
#      69         return False
# ---> 71 asyncio.run(write_to_sheet(llm_output))
#
# File c:\Users\SarthakPandey\AppData\Local\anaconda3\envs\resourcex\Lib\asyncio\runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
